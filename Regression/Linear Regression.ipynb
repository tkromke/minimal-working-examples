# %% [markdown]
# # Linear Regression Example

# %% [markdown]
# Minimal working example for a Linear Regression using sklearn. The dataset is purposely kept small as it's only supposed to give a simple setup draft for a Linear Regression.

# %% [markdown]
# ## 1. load example Data

# %% [markdown]
# Loading the data. In this case we use a very small version of the iris dataset, to provide a minimal working example.

# %%
import pandas as pd

df = pd.read_csv(".././Data/iris.csv")
#df.head()

# %% [markdown]
# ## 2. prepare data

# %% [markdown]
# Spot for data preparation. As this example is quiet simple to have a basic refference we just drop the unsude ID.

# %%
df = df.drop("Id", axis = 1)

# %% [markdown]
# ## 3. set parameters

# %% [markdown]
# Space to set different parameters to allow for easy adjustments and keep a clean structure.

# %%
test_size = 0.25
random_state = 0

# %% [markdown]
# ## 4. train test split

# %% [markdown]
# Create a train test split based on test_size set in parameters.

# %%
from sklearn.model_selection import train_test_split

X = df[ df.columns[df.columns!='PetalLengthCm']].values
X = df[["SepalLengthCm", "SepalWidthCm"]].values
Y = df[["PetalLengthCm"]].values

X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state = random_state, test_size = test_size)

# %% [markdown]
# ## 5. Standardscaler

# %% [markdown]
# Standadize values, so that the distance between them loweredby generalization which makes it easier for the model to work with.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 6. train model

# %% [markdown]
# Train the model.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 7. validate model

# %% [markdown]
# Validate the model using different methods like a simple score, calculated values for precision and recall or via a printed confusion matrix.

# %%
print(model.score(X_test, y_test))
# Out:
# 0.8115556956422382

# %% [markdown]
# ### 7.1 visualize results

# %%
from helper import plot_classifier

plot_classifier(model, X_train, y_train, proba = False, xlabel = "", ylabel = "")

# %%
from helper import plot_classifier

plot_classifier(model, X_test, y_test, proba = False, xlabel = "", ylabel = "")

# %%
y_test_pred = model.predict(X_test)

for i in range(0, len(y_test_pred)):
    print(str(y_test_pred[i]) + " - " + str(y_test[i]))
# Out:
# [3.96169391] - [5.1]
# [5.08609643] - [4.]
# [1.63771456] - [1.4]
# [6.53085761] - [6.3]
# [1.75863586] - [1.5]
# [4.22319795] - [6.]
# [1.63116074] - [1.3]
# [5.19725186] - [4.7]
# [5.75945312] - [4.8]
# [4.50102167] - [4.]
# [4.7559719] - [5.6]
# [4.53044898] - [4.5]
# [4.50102167] - [4.7]
# [5.22012536] - [4.6]
# [4.37354656] - [4.7]
# [1.96128527] - [1.5]
# [4.19377064] - [4.5]
# [3.67731637] - [4.4]
# [1.90898447] - [1.4]
# [1.84036398] - [1.3]
# [3.60214206] - [4.9]
# [3.34719184] - [4.5]
# [1.39908401] - [1.9]
# [1.31735589] - [1.4]
# [4.68079759] - [4.8]
# [0.78458195] - [1.]
# [1.42851133] - [1.9]
# [4.55332248] - [4.3]
# [3.1608621] - [3.3]
# [1.75863586] - [1.6]
# [4.6579241] - [5.5]
# [2.98763999] - [4.5]
# [1.99071259] - [1.5]
# [4.24607144] - [4.9]
# [5.04034943] - [5.6]
# [3.01051349] - [3.9]
# [2.50716686] - [1.7]
# [4.44872086] - [5.1]
